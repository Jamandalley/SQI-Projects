# %% [markdown]
# # IMPORTING DATASETS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# UNEMPLYMENT RATE
unemployment_rate = pd.read_csv(r"C:\Users\USER\Desktop\ABIMS\10Alytics Hackathon Datasets\1. unemployment-rate-men-vs-women.csv")
unemployment_rate
# Out:
#             Entity      Code  Year  \
# 0         Abkhazia  OWID_ABK  2015
# 1      Afghanistan       AFG  1991
# 2      Afghanistan       AFG  1992
# 3      Afghanistan       AFG  1993
# 4      Afghanistan       AFG  1994
# ...            ...       ...   ...
# 58573     Zimbabwe       ZWE  1986
# 58574     Zimbabwe       ZWE  1987
# 58575     Zimbabwe       ZWE  1988
# 58576     Zimbabwe       ZWE  1989
# 58577     Zimbabwe       ZWE  1990
#
#        Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                    NaN
# 1                                                 13.615
# 2                                                 13.816
# 3                                                 13.712
# 4                                                 13.722
# ...                                                  ...
# 58573                                                NaN
# 58574                                                NaN
# 58575                                                NaN
# 58576                                                NaN
# 58577                                                NaN
#
#        Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                                    NaN
# 1                                                 10.089
# 2                                                 10.258
# 3                                                 10.165
# 4                                                 10.170
# ...                                                  ...
# 58573                                                NaN
# 58574                                                NaN
# 58575                                                NaN
# 58576                                                NaN
# 58577                                                NaN
#
#        Population (historical estimates) Continent
# 0                                    NaN      Asia
# 1                             10745168.0       NaN
# 2                             12057436.0       NaN
# 3                             14003764.0       NaN
# 4                             15455560.0       NaN
# ...                                  ...       ...
# 58573                          8983048.0       NaN
# 58574                          9277484.0       NaN
# 58575                          9568745.0       NaN
# 58576                          9846352.0       NaN
# 58577                         10113899.0       NaN
#
# [58578 rows x 7 columns]

# %%
# THE NATIONAL STRATEGY FOR YOUTH EMPLOYMENT
national_strategy = pd.read_csv(r"C:\Users\USER\Desktop\ABIMS\10Alytics Hackathon Datasets\2. national-strategy-for-youth-employment.csv")
national_strategy
# Out:
#           Entity Code  Year  \
# 0    Afghanistan  AFG  2019
# 1    Afghanistan  AFG  2020
# 2      Argentina  ARG  2019
# 3      Argentina  ARG  2020
# 4      Argentina  ARG  2021
# ..           ...  ...   ...
# 358       Zambia  ZMB  2019
# 359       Zambia  ZMB  2020
# 360       Zambia  ZMB  2022
# 361     Zimbabwe  ZWE  2019
# 362     Zimbabwe  ZWE  2020
#
#      8.b.1 - Existence of a developed and operationalized national strategy for youth employment, as a distinct strategy or as part of a national employment strategy - SL_CPA_YEMP
# 0                                                    1
# 1                                                    1
# 2                                                    0
# 3                                                    0
# 4                                                    3
# ..                                                 ...
# 358                                                  2
# 359                                                  2
# 360                                                  2
# 361                                                  1
# 362                                                  1
#
# [363 rows x 4 columns]

# %%
# SHARE OF EDUcATION IN GOVERNMENT EXPENDITURE
education_share = pd.read_csv(r"C:\Users\USER\Desktop\ABIMS\10Alytics Hackathon Datasets\3. share-of-education-in-government-expenditure.csv")
education_share
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2005
# 1     Afghanistan  AFG  2006
# 2     Afghanistan  AFG  2007
# 3     Afghanistan  AFG  2008
# 4     Afghanistan  AFG  2009
# ...           ...  ...   ...
# 4099     Zimbabwe  ZWE  2015
# 4100     Zimbabwe  ZWE  2016
# 4101     Zimbabwe  ZWE  2017
# 4102     Zimbabwe  ZWE  2018
# 4103     Zimbabwe  ZWE  2020
#
#       Government expenditure on education, total (% of government expenditure)
# 0                                             15.080000
# 1                                             12.880000
# 2                                             12.360000
# 3                                             16.650000
# 4                                             17.310000
# ...                                                 ...
# 4099                                          29.470830
# 4100                                          23.527080
# 4101                                          20.874200
# 4102                                          19.039840
# 4103                                          15.666611
#
# [4104 rows x 4 columns]

# %%
# SHARE OF POPULATION WITH ACCESS TO ELECTRICITY 
access_to_electricity = pd.read_csv(r"C:\Users\USER\Desktop\ABIMS\10Alytics Hackathon Datasets\4. share-of-the-population-with-access-to-electricity.csv")
access_to_electricity
# Out:
#            Entity Code  Year  Access to electricity (% of population)
# 0     Afghanistan  AFG  2000                                 1.613591
# 1     Afghanistan  AFG  2001                                 4.074574
# 2     Afghanistan  AFG  2002                                 9.409158
# 3     Afghanistan  AFG  2003                                14.738506
# 4     Afghanistan  AFG  2004                                20.064968
# ...           ...  ...   ...                                      ...
# 6228     Zimbabwe  ZWE  2016                                42.561730
# 6229     Zimbabwe  ZWE  2017                                44.178635
# 6230     Zimbabwe  ZWE  2018                                45.572647
# 6231     Zimbabwe  ZWE  2019                                46.781475
# 6232     Zimbabwe  ZWE  2020                                52.747670
#
# [6233 rows x 4 columns]

# %%
# TOTAL FIRM HISTORY 
firm_history = pd.read_excel(r"C:\Users\USER\Desktop\ABIMS\10Alytics Hackathon Datasets\5. Total_firms_Historical_data.xlsx")
firm_history
# Out:
#                                                 Economy  Adult population  \
# 0                                           Afghanistan        14039528.0
# 1                                           Afghanistan        14444996.0
# 2                                           Afghanistan        15041824.0
# 3                                           Afghanistan        15743958.0
# 4                                           Afghanistan        16519812.0
# ...                                                 ...               ...
# 1521                                           Zimbabwe         8185716.0
# 1522                                                NaN               NaN
# 1523  * This economy was included in the Eurostat Li...               NaN
# 1524  ** For Canada, only the data for Quebec and On...               NaN
# 1525  ***For China, only the data for Beijing and Sh...               NaN
#
#         Year  TOTAL Number of \nLimited Liability Companies  \
# 0     2009.0                                         4289.0
# 1     2010.0                                         9048.0
# 2     2011.0                                        12793.0
# 3     2012.0                                        16350.0
# 4     2013.0                                        19541.0
# ...      ...                                            ...
# 1521  2020.0                                       230256.0
# 1522     NaN                                            NaN
# 1523     NaN                                            NaN
# 1524     NaN                                            NaN
# 1525     NaN                                            NaN
#
#       Total business density rate
# 0                        0.305495
# 1                        0.626376
# 2                        0.850495
# 3                        1.038494
# 4                        1.182883
# ...                           ...
# 1521                    28.128999
# 1522                          NaN
# 1523                          NaN
# 1524                          NaN
# 1525                          NaN
#
# [1526 rows x 5 columns]

# %%
# COUNTRY CODES
country_code = pd.read_csv(r"C:\Users\USER\Desktop\ABIMS\10Alytics Hackathon Datasets\6. Country Codes.csv")
country_code
# Out:
#                   name alpha-2 alpha-3  country-code   region  \
# 0          Afghanistan      AF     AFG             4     Asia
# 1        Åland Islands      AX     ALA           248   Europe
# 2              Albania      AL     ALB             8   Europe
# 3              Algeria      DZ     DZA            12   Africa
# 4       American Samoa      AS     ASM            16  Oceania
# ..                 ...     ...     ...           ...      ...
# 244  Wallis and Futuna      WF     WLF           876  Oceania
# 245     Western Sahara      EH     ESH           732   Africa
# 246              Yemen      YE     YEM           887     Asia
# 247             Zambia      ZM     ZMB           894   Africa
# 248           Zimbabwe      ZW     ZWE           716   Africa
#
#              sub-region
# 0         Southern Asia
# 1       Northern Europe
# 2       Southern Europe
# 3       Northern Africa
# 4             Polynesia
# ..                  ...
# 244           Polynesia
# 245     Northern Africa
# 246        Western Asia
# 247  Sub-Saharan Africa
# 248  Sub-Saharan Africa
#
# [249 rows x 6 columns]

# %% [markdown]
# # A QUICK LOOK AT THE DATA STRUCTURE (DATA EXPLORATION)

# %%
unemployment_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58578 entries, 0 to 58577
# Data columns (total 7 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Entity                                                                 58578 non-null  object
#  1   Code                                                                   55049 non-null  object
#  2   Year                                                                   58578 non-null  int64
#  3   Unemployment, female (% of female labor force) (modeled ILO estimate)  6231 non-null   float64
#  4   Unemployment, male (% of male labor force) (modeled ILO estimate)      6231 non-null   float64
#  5   Population (historical estimates)                                      58252 non-null  float64
#  6   Continent                                                              285 non-null    object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# It is observed that the unemployment rate contains 58578 entries (samples) and 7 columns (features). The country code (code), unemployment female, unemployment male, Population and Continent columns contain some null values

# %%
national_strategy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 4 columns):
#  #   Column                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                          --------------  -----
#  0   Entity                                                                                                                                                                          363 non-null    object
#  1   Code                                                                                                                                                                            363 non-null    object
#  2   Year                                                                                                                                                                            363 non-null    int64
#  3   8.b.1 - Existence of a developed and operationalized national strategy for youth employment, as a distinct strategy or as part of a national employment strategy - SL_CPA_YEMP  363 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 11.5+ KB

# %% [markdown]
# The national strategy table contains 4 columns and 363 entries. None of the columns contain null values

# %%
education_share.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4104 entries, 0 to 4103
# Data columns (total 4 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Entity                                                                    4104 non-null   object
#  1   Code                                                                      3809 non-null   object
#  2   Year                                                                      4104 non-null   int64
#  3   Government expenditure on education, total (% of government expenditure)  4104 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 128.4+ KB

# %% [markdown]
# Only the country code in table education share contains null value

# %%
access_to_electricity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6233 entries, 0 to 6232
# Data columns (total 4 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Entity                                   6233 non-null   object
#  1   Code                                     5863 non-null   object
#  2   Year                                     6233 non-null   int64
#  3   Access to electricity (% of population)  6233 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 194.9+ KB

# %% [markdown]
# Similarly, in the access to electricity table, only the country code contains Null value

# %%
firm_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1526 entries, 0 to 1525
# Data columns (total 5 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Economy                                       1525 non-null   object
#  1   Adult population                              1522 non-null   float64
#  2   Year                                          1522 non-null   float64
#  3   TOTAL Number of
# Limited Liability Companies  1522 non-null   float64
#  4   Total business density rate                   1522 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 59.7+ KB

# %% [markdown]
# All the features in the firm history table contains null vlaue

# %%
country_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          249 non-null    object
#  1   alpha-2       248 non-null    object
#  2   alpha-3       249 non-null    object
#  3   country-code  249 non-null    int64
#  4   region        248 non-null    object
#  5   sub-region    248 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 11.8+ KB

# %% [markdown]
# # DATA CLEANING, PREPARATION AND ANALYSIS
# 1. UNEMPLOYMENT RATE

# %%
unemployment_rate.describe()
# Out:
#                Year  \
# count  58578.000000
# mean    1603.516542
# std     1424.962569
# min   -10000.000000
# 25%     1832.000000
# 50%     1901.000000
# 75%     1966.000000
# max     2021.000000
#
#        Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# count                                        6231.000000
# mean                                            9.460057
# std                                             7.613245
# min                                             0.149000
# 25%                                             4.052500
# 50%                                             6.908000
# 75%                                            12.771000
# max                                            47.183000
#
#        Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# count                                        6231.000000
# mean                                            7.567807
# std                                             5.688615
# min                                             0.052000
# 25%                                             3.612000
# 50%                                             5.890000
# 75%                                            10.037500
# max                                            36.963000
#
#        Population (historical estimates)
# count                       5.825200e+04
# mean                        4.901082e+07
# std                         2.925549e+08
# min                         0.000000e+00
# 25%                         1.460840e+05
# 50%                         1.388504e+06
# 75%                         6.600998e+06
# max                         7.909295e+09

# %%
# Since we're only interested in the unemployment rate, use the unemployment rate column to filter the table
unemployment_rate = unemployment_rate.dropna(subset=['Unemployment, female (% of female labor force) (modeled ILO estimate)', 'Unemployment, male (% of male labor force) (modeled ILO estimate)'])
Africa_unemployment_rate = pd.merge(unemployment_rate, country_code, left_on='Entity', right_on='name', how='left')
columns_to_drop = ['name', 'alpha-2', 'alpha-3', 'country-code', 'sub-region', 'Continent']
columns_to_drop = [col for col in columns_to_drop if col in Africa_unemployment_rate.columns]
Africa_unemployment_rate.drop(columns=columns_to_drop, inplace=True)
Africa_unemployment_rate = Africa_unemployment_rate.rename(columns={'region': 'Continent', 'Entity': 'Country'})
Africa_unemployment_rate.reset_index()
# Out:
#       index      Country Code  Year  \
# 0         0  Afghanistan  AFG  1991
# 1         1  Afghanistan  AFG  1992
# 2         2  Afghanistan  AFG  1993
# 3         3  Afghanistan  AFG  1994
# 4         4  Afghanistan  AFG  1995
# ...     ...          ...  ...   ...
# 6226   6226     Zimbabwe  ZWE  2017
# 6227   6227     Zimbabwe  ZWE  2018
# 6228   6228     Zimbabwe  ZWE  2019
# 6229   6229     Zimbabwe  ZWE  2020
# 6230   6230     Zimbabwe  ZWE  2021
#
#       Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                13.615
# 1                                                13.816
# 2                                                13.712
# 3                                                13.722
# 4                                                14.235
# ...                                                 ...
# 6226                                              5.192
# 6227                                              5.206
# 6228                                              5.248
# 6229                                              5.791
# 6230                                              5.690
#
#       Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                                10.089
# 1                                                10.258
# 2                                                10.165
# 3                                                10.170
# 4                                                10.610
# ...                                                 ...
# 6226                                              4.353
# 6227                                              4.360
# 6228                                              4.393
# 6229                                              4.890
# 6230                                              4.634
#
#       Population (historical estimates) Continent
# 0                            10745168.0      Asia
# 1                            12057436.0      Asia
# 2                            14003764.0      Asia
# 3                            15455560.0      Asia
# 4                            16418911.0      Asia
# ...                                 ...       ...
# 6226                         14751101.0    Africa
# 6227                         15052191.0    Africa
# 6228                         15354606.0    Africa
# 6229                         15669663.0    Africa
# 6230                         15993525.0    Africa
#
# [6231 rows x 8 columns]

# %%
Africa_unemployment_rate['Continent'] = Africa_unemployment_rate['Continent'].str.strip()
A_unemployment_rate = Africa_unemployment_rate[Africa_unemployment_rate['Continent'] == 'Africa']
A_unemployment_rate
# Out:
#        Country Code  Year  \
# 62     Algeria  DZA  1991
# 63     Algeria  DZA  1992
# 64     Algeria  DZA  1993
# 65     Algeria  DZA  1994
# 66     Algeria  DZA  1995
# ...        ...  ...   ...
# 6226  Zimbabwe  ZWE  2017
# 6227  Zimbabwe  ZWE  2018
# 6228  Zimbabwe  ZWE  2019
# 6229  Zimbabwe  ZWE  2020
# 6230  Zimbabwe  ZWE  2021
#
#       Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 62                                               16.585
# 63                                               20.720
# 64                                               23.305
# 65                                               25.718
# 66                                               30.738
# ...                                                 ...
# 6226                                              5.192
# 6227                                              5.206
# 6228                                              5.248
# 6229                                              5.791
# 6230                                              5.690
#
#       Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 62                                               21.170
# 63                                               24.904
# 64                                               26.652
# 65                                               28.034
# 66                                               32.003
# ...                                                 ...
# 6226                                              4.353
# 6227                                              4.360
# 6228                                              4.393
# 6229                                              4.890
# 6230                                              4.634
#
#       Population (historical estimates) Continent
# 62                           26133906.0    Africa
# 63                           26748302.0    Africa
# 64                           27354326.0    Africa
# 65                           27937006.0    Africa
# 66                           28478024.0    Africa
# ...                                 ...       ...
# 6226                         14751101.0    Africa
# 6227                         15052191.0    Africa
# 6228                         15354606.0    Africa
# 6229                         15669663.0    Africa
# 6230                         15993525.0    Africa
#
# [1519 rows x 7 columns]

# %%
A_unemployment_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1519 entries, 62 to 6230
# Data columns (total 7 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Country                                                                1519 non-null   object
#  1   Code                                                                   1519 non-null   object
#  2   Year                                                                   1519 non-null   int64
#  3   Unemployment, female (% of female labor force) (modeled ILO estimate)  1519 non-null   float64
#  4   Unemployment, male (% of male labor force) (modeled ILO estimate)      1519 non-null   float64
#  5   Population (historical estimates)                                      1519 non-null   float64
#  6   Continent                                                              1519 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 94.9+ KB

# %%
A_unemployment_rate.isnull().sum()
# Out:
# Country                                                                  0
# Code                                                                     0
# Year                                                                     0
# Unemployment, female (% of female labor force) (modeled ILO estimate)    0
# Unemployment, male (% of male labor force) (modeled ILO estimate)        0
# Population (historical estimates)                                        0
# Continent                                                                0
# dtype: int64

# %%
africa_unemployment_rate = A_unemployment_rate.copy()
africa_unemployment_rate.rename(columns={'Unemployment, female (% of female labor force) (modeled ILO estimate)': 'Unemployment in female',
                                        'Unemployment, male (% of male labor force) (modeled ILO estimate)': 'Unemployment in male',
                                         'Population (historical estimates)': 'Population'}, inplace=True)
africa_unemployment_rate.drop(columns='Continent')
africa_unemployment_rate
# Out:
#        Country Code  Year  Unemployment in female  Unemployment in male  \
# 62     Algeria  DZA  1991                  16.585                21.170
# 63     Algeria  DZA  1992                  20.720                24.904
# 64     Algeria  DZA  1993                  23.305                26.652
# 65     Algeria  DZA  1994                  25.718                28.034
# 66     Algeria  DZA  1995                  30.738                32.003
# ...        ...  ...   ...                     ...                   ...
# 6226  Zimbabwe  ZWE  2017                   5.192                 4.353
# 6227  Zimbabwe  ZWE  2018                   5.206                 4.360
# 6228  Zimbabwe  ZWE  2019                   5.248                 4.393
# 6229  Zimbabwe  ZWE  2020                   5.791                 4.890
# 6230  Zimbabwe  ZWE  2021                   5.690                 4.634
#
#       Population Continent
# 62    26133906.0    Africa
# 63    26748302.0    Africa
# 64    27354326.0    Africa
# 65    27937006.0    Africa
# 66    28478024.0    Africa
# ...          ...       ...
# 6226  14751101.0    Africa
# 6227  15052191.0    Africa
# 6228  15354606.0    Africa
# 6229  15669663.0    Africa
# 6230  15993525.0    Africa
#
# [1519 rows x 7 columns]

# %%
# PREVALENCE OF UNEMPLOYMENT IN AFRICA
prevalence_of_unemployment = africa_unemployment_rate.groupby(['Country'])[['Unemployment in female', 'Unemployment in male']].mean()
prevalence_of_unemployment['Average Prevalence'] = (prevalence_of_unemployment['Unemployment in female'] + prevalence_of_unemployment['Unemployment in male'])/2
prevalence_of_unemployment = prevalence_of_unemployment.sort_values(by='Average Prevalence', ascending=False)
prevalence_of_unemployment.head()
# Out:
#               Unemployment in female  Unemployment in male  Average Prevalence
# Country
# Djibouti                   37.281548             24.829935           31.055742
# Lesotho                    35.324452             25.776129           30.550290
# South Africa               32.754806             24.938903           28.846855
# Eswatini                   26.765419             22.235903           24.500661
# Libya                      25.875903             16.479903           21.177903

# %%
import warnings
warnings.filterwarnings("ignore")
df = prevalence_of_unemployment.head()
df['country'] = np.array(df.index)
df
# Out:
#               Unemployment in female  Unemployment in male  \
# Country
# Djibouti                   37.281548             24.829935
# Lesotho                    35.324452             25.776129
# South Africa               32.754806             24.938903
# Eswatini                   26.765419             22.235903
# Libya                      25.875903             16.479903
#
#               Average Prevalence       country
# Country
# Djibouti               31.055742      Djibouti
# Lesotho                30.550290       Lesotho
# South Africa           28.846855  South Africa
# Eswatini               24.500661      Eswatini
# Libya                  21.177903         Libya

# %%
df1 = prevalence_of_unemployment.tail().sort_values(by='Average Prevalence')
df1['country'] = df1.index.values
df1
# Out:
#          Unemployment in female  Unemployment in male  Average Prevalence  \
# Country
# Chad                   0.561645              1.243258            0.902452
# Rwanda                 0.832452              1.002774            0.917613
# Benin                  1.179129              1.458742            1.318935
# Niger                  1.171387              1.547645            1.359516
# Burundi                1.220032              2.007000            1.613516
#
#          country
# Country
# Chad        Chad
# Rwanda    Rwanda
# Benin      Benin
# Niger      Niger
# Burundi  Burundi

# %%
# Bar Chart Representation of Top 5 countries with the highest prevalence of Unemployment 
# %matplotlib inline
sns.set(style='ticks', color_codes=True)
sns.set(style='darkgrid')
fig, ax = plt.subplots(1, 2, figsize =(13, 4))
#For non-binarized data
sns.barplot(x='country', y='Average Prevalence', data=df, ax=ax[0])
ax[0].set_title('Top 5 African Countries with the highest Unemployment Rate')
ax[0].set_xlabel('Countries')
ax[0].set_ylabel('Average Prevalence')
for p in ax[0].patches:
    ax[0].annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 10), 
                   textcoords = 'offset points')



sns.barplot(x='country', y='Average Prevalence', data=df1, ax=ax[1])
ax[1].set_title('Top 5 African Countries with the Least Unemployment Rate')
ax[1].set_xlabel('Countries')
ax[1].set_label('Average Prevalence')
for p in ax[1].patches:
    ax[1].annotate(format(p.get_height(), '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 10), 
                   textcoords = 'offset points')


plt.show()

# %% [markdown]
# # Unemployment trend in these countries

# %%
trend = africa_unemployment_rate.copy()
trend['Average unemployment'] = (trend['Unemployment in female'] + trend['Unemployment in male'])/2
trend
# Out:
#        Country Code  Year  Unemployment in female  Unemployment in male  \
# 62     Algeria  DZA  1991                  16.585                21.170
# 63     Algeria  DZA  1992                  20.720                24.904
# 64     Algeria  DZA  1993                  23.305                26.652
# 65     Algeria  DZA  1994                  25.718                28.034
# 66     Algeria  DZA  1995                  30.738                32.003
# ...        ...  ...   ...                     ...                   ...
# 6226  Zimbabwe  ZWE  2017                   5.192                 4.353
# 6227  Zimbabwe  ZWE  2018                   5.206                 4.360
# 6228  Zimbabwe  ZWE  2019                   5.248                 4.393
# 6229  Zimbabwe  ZWE  2020                   5.791                 4.890
# 6230  Zimbabwe  ZWE  2021                   5.690                 4.634
#
#       Population Continent  Average unemployment
# 62    26133906.0    Africa               18.8775
# 63    26748302.0    Africa               22.8120
# 64    27354326.0    Africa               24.9785
# 65    27937006.0    Africa               26.8760
# 66    28478024.0    Africa               31.3705
# ...          ...       ...                   ...
# 6226  14751101.0    Africa                4.7725
# 6227  15052191.0    Africa                4.7830
# 6228  15354606.0    Africa                4.8205
# 6229  15669663.0    Africa                5.3405
# 6230  15993525.0    Africa                5.1620
#
# [1519 rows x 8 columns]

# %%
top_5 = df.index.values
colors=['b', 'g', 'r', 'k', 'c' ]

for index, country in enumerate(top_5):
    country_data = trend[trend['Country'] == country]
    plt.plot(country_data['Year'], country_data['Average unemployment'], c=colors[index], label=country)

plt.legend()
plt.show()

# %%
least_5 = df1.index.values
colors=['b', 'g', 'r', 'k', 'c' ]

for index, country in enumerate(least_5):
    country_data = trend[trend['Country'] == country]
    plt.plot(country_data['Year'], country_data['Average unemployment'], c=colors[index], label=country)

plt.legend()
plt.show()

# %% [markdown]
# # General Overview of Unemployment in Africa

# %%
import plotly.graph_objects as go
continental_view = africa_unemployment_rate.copy()
continental_view['Average unemployment'] = (continental_view['Unemployment in female'] + continental_view['Unemployment in male'])/2
# x = continental_view.groupby(['Country'])['Average unemployment'].mean()

# hover_text = [f'Country: {country}<br>Unemployment rate: {unemployment:.2f}' 
#               for country, unemployment in zip(continental_view['Country'], x.values)]

figure = go.Figure(data=go.Choropleth(
    locations=continental_view['Code'],
    z=continental_view['Average unemployment'].astype(float),
    locationmode="ISO-3",
    colorscale="Reds",
    colorbar_title="Average Unemployment"
))

figure.update_layout(
    title_text="General Overview of Unemployment Rate in African Countries",
    geo=dict(scope='africa'),
    width=800,
    height=600
)


figure.show()
# Out:
# <div>                            <div id="112ecd15-903f-4ee7-89c5-98151d037338" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("112ecd15-903f-4ee7-89c5-98151d037338")) {                    Plotly.newPlot(                        "112ecd15-903f-4ee7-89c5-98151d037338",                        [{"colorbar":{"title":{"text":"Average Unemployment"}},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"locationmode":"ISO-3","locations":["DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","DZA","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BFA","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","BDI","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","CAF","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","TCD","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COM","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","COG","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","DJI","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","EGY","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","GNQ","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","ERI","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","SWZ","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH","ETH", ...

# %% [markdown]
# # Variation of Unemployment with Population

# %%
top_5 = df.index.values

top_5_data = trend[trend['Country'].isin(top_5)]
fig = px.scatter(top_5_data, 
                 x=top_5_data['Population'],
                 y="Average unemployment",
                 size="Average unemployment",
                 color="Country",
                 hover_name="Country",
                 title="Variation of Unemployment with Population")

fig.show()
# Out:
# <div>                            <div id="00b868cb-0518-405d-bf42-5cd2d8edbd45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00b868cb-0518-405d-bf42-5cd2d8edbd45")) {                    Plotly.newPlot(                        "00b868cb-0518-405d-bf42-5cd2d8edbd45",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Djibouti<br>Population=%{x}<br>Average unemployment=%{marker.size}<extra></extra>","hovertext":["Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti"],"legendgroup":"Djibouti","marker":{"color":"#636efa","size":[32.548,32.408,32.416,32.252,32.197,32.1045,31.984499999999997,31.883,31.7515,31.6685,31.546499999999998,31.4035,31.273,31.153,31.037,30.883499999999998,30.7625,30.636000000000003,30.563499999999998,30.3935,30.238,30.142000000000003,30.007,29.8425,29.6905,29.5845,29.460499999999996,29.5045,29.599,31.838,31.9565],"sizemode":"area","sizeref":0.095595,"symbol":"circle"},"mode":"markers","name":"Djibouti","orientation":"v","showlegend":true,"x":[628528.0,623208.0,611239.0,623482.0,629628.0,644659.0,667793.0,694931.0,719381.0,742046.0,765496.0,789140.0,806412.0,818380.0,830863.0,846957.0,865202.0,882893.0,901106.0,919206.0,936819.0,954311.0,971761.0,989091.0,1006266.0,1023269.0,1040242.0,1057204.0,1073999.0,1090162.0,1105562.0],"xaxis":"x","y":[32.548,32.408,32.416,32.252,32.197,32.1045,31.984499999999997,31.883,31.7515,31.6685,31.546499999999998,31.4035,31.273,31.153,31.037,30.883499999999998,30.7625,30.636000000000003,30.563499999999998,30.3935,30.238,30.142000000000003,30.007,29.8425,29.6905,29.5845,29.460499999999996,29.5045,29.599,31.838,31.9565],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Eswatini<br>Population=%{x}<br>Average unemployment=%{marker.size}<extra></extra>","hovertext":["Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini"],"legendgroup":"Eswatini","marker":{"color":"#EF553B","size":[21.945,21.8975,21.8675,21.8415,21.7765,22.2745,22.759999999999998,23.3295,23.8845,24.4555,25.019,25.5285,26.0875,26.6425,27.16,27.7165,28.299,27.7205,27.082,26.427500000000002,25.8365,25.181,24.588,24.0125,23.382,22.7715,22.808500000000002,22.8525,22.9,25.606,25.866999999999997],"sizemode":"area","sizeref":0.095595,"symbol":"circle"},"mode":"markers","name":"Eswatini","orientation":"v","showlegend":true,"x":[889719.0,925170.0,953454.0,953745.0,953586.0,973593.0,990740.0,1005162.0,1018383.0,1030504.0,1041400.0,1050818.0,1058808.0,1065776.0,1071895.0,1077747.0,1084015.0,1089885.0,1094890.0,1099926.0,1105379.0,1111453.0,1118329.0,1125872.0,1133941.0,1142529.0,1151397.0,1160430.0,1169620.0,1180663.0,1192273.0],"xaxis":"x","y":[21.945,21.8975,21.8675,21.8415,21.7765,22.2745,22.759999999999998,23.3295,23.8845,24.4555,25.019,25.5285,26.0875,26.6425,27.16,27.7165,28.299,27.7205,27.082,26.427500000000002,25.8365,25.181,24.588,24.0125,23.382,22.7715,22.808500000000002,22.8525,22.9,25.606,25.866999999999997],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Lesotho<br>Population=%{x}<br>Average unemployment=%{marker.size}<extra></extra>","hovertext":["Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","L ...

# %%
fig_linear = px.line(top_5_data, 
                     x=np.log(top_5_data["Population"]),
                     y="Average unemployment",
                     color="Country",
                     hover_name="Country",
                     title="Linear Relationship")

fig_linear.show()
# Out:
# <div>                            <div id="e1fc18d7-7c8b-4f29-bde2-2afbcd3206c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1fc18d7-7c8b-4f29-bde2-2afbcd3206c8")) {                    Plotly.newPlot(                        "e1fc18d7-7c8b-4f29-bde2-2afbcd3206c8",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Djibouti<br>x=%{x}<br>Average unemployment=%{y}<extra></extra>","hovertext":["Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti","Djibouti"],"legendgroup":"Djibouti","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Djibouti","orientation":"v","showlegend":true,"x":[13.351135856537198,13.342635610426758,13.32324332369927,13.343075174399216,13.352884447777518,13.376476773805672,13.411733524256459,13.451567839042747,13.486146398996917,13.517166514837095,13.54827926872331,13.578699023884644,13.600350057140902,13.615082055393279,13.6302201986339,13.649405204931078,13.670718284662623,13.69095929444053,13.711378176729426,13.731265532910523,13.75024537287039,13.768744893112464,13.786865168434296,13.80454161850546,13.821757008209614,13.838512962469581,13.854963936356592,13.87113824528438,13.886899622951818,13.901836867015106,13.915864360927296],"xaxis":"x","y":[32.548,32.408,32.416,32.252,32.197,32.1045,31.984499999999997,31.883,31.7515,31.6685,31.546499999999998,31.4035,31.273,31.153,31.037,30.883499999999998,30.7625,30.636000000000003,30.563499999999998,30.3935,30.238,30.142000000000003,30.007,29.8425,29.6905,29.5845,29.460499999999996,29.5045,29.599,31.838,31.9565],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Eswatini<br>x=%{x}<br>Average unemployment=%{y}<extra></extra>","hovertext":["Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini","Eswatini"],"legendgroup":"Eswatini","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Eswatini","orientation":"v","showlegend":true,"x":[13.698660961517927,13.737732783392175,13.767846459544758,13.768151619103104,13.767984893977399,13.788748630818597,13.806207417638129,13.820659280514802,13.833726633234475,13.845558560915986,13.856076519710935,13.86507946645267,13.87265430503,13.879213730295163,13.884938668054495,13.89038330902861,13.896182298524366,13.90158274405217,13.906164459565629,13.910753462778414,13.915698820552931,13.921178726292164,13.92734616489859,13.93406840448829,13.941209733697624,13.948754784360522,13.956486545696741,13.964301184049283,13.972189467694651,13.981586703061922,13.991372127230425],"xaxis":"x","y":[21.945,21.8975,21.8675,21.8415,21.7765,22.2745,22.759999999999998,23.3295,23.8845,24.4555,25.019,25.5285,26.0875,26.6425,27.16,27.7165,28.299,27.7205,27.082,26.427500000000002,25.8365,25.181,24.588,24.0125,23.382,22.7715,22.808500000000002,22.8525,22.9,25.606,25.866999999999997],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Lesotho<br>x=%{x}<br>Average unemployment=%{y}<extra></extra>","hovertext":["Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesotho","Lesot ...

# %% [markdown]
# # 2. NATIONAL STRATEGY

# %%
national_strategy
n_national_strategy = national_strategy.copy()
n_national_strategy.rename(columns={'8.b.1 - Existence of a developed and operationalized national strategy for youth employment, as a distinct strategy or as part of a national employment strategy - SL_CPA_YEMP': 'Existence of National Strategy', 'Entity': 'Country'}, inplace=True)
n_national_strategy.replace({0:'No strategy', 1:'Developing a strategy', 2: 'Strategy adopted', 3: 'Strategy operationalized'}, inplace=True)

# %%
strategy_counts = n_national_strategy.groupby(['Year', 'Existence of National Strategy']).size().unstack()
strategy_counts
# Out:
# Existence of National Strategy  Developing a strategy  No strategy  \
# Year
# 2019                                               26            2
# 2020                                               27            3
# 2021                                               10            3
# 2022                                               10            1
#
# Existence of National Strategy  Strategy adopted  Strategy operationalized
# Year
# 2019                                          41                        33
# 2020                                          44                        33
# 2021                                          25                        43
# 2022                                          21                        41

# %%
# Plot the data
strategy_counts.plot(kind='bar', figsize=(10, 4))

# Add labels and title
plt.title("Existence of National Strategy by Year")
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show the plot
plt.legend(title='National Strategy')
plt.tight_layout()
plt.show()

# %%
african_countries = africa_unemployment_rate['Country'].unique()

# %%
africa_NS = n_national_strategy[n_national_strategy['Country'].isin(african_countries)]
africa_NS
# Out:
#           Country Code  Year Existence of National Strategy
# 36          Benin  BEN  2019               Strategy adopted
# 37          Benin  BEN  2020               Strategy adopted
# 44       Botswana  BWA  2019          Developing a strategy
# 45       Botswana  BWA  2020          Developing a strategy
# 49   Burkina Faso  BFA  2019               Strategy adopted
# ..            ...  ...   ...                            ...
# 358        Zambia  ZMB  2019               Strategy adopted
# 359        Zambia  ZMB  2020               Strategy adopted
# 360        Zambia  ZMB  2022               Strategy adopted
# 361      Zimbabwe  ZWE  2019          Developing a strategy
# 362      Zimbabwe  ZWE  2020          Developing a strategy
#
# [83 rows x 4 columns]

# %%
africa_strategy_counts = africa_NS.groupby(['Year', 'Existence of National Strategy']).size().unstack()
africa_strategy_counts
# Out:
# Existence of National Strategy  Developing a strategy  Strategy adopted  \
# Year
# 2019                                                9                15
# 2020                                                9                15
# 2021                                                3                 7
# 2022                                                4                 6
#
# Existence of National Strategy  Strategy operationalized
# Year
# 2019                                                   6
# 2020                                                   6
# 2021                                                   2
# 2022                                                   1

# %%
africa_strategy_counts.plot(kind='bar', figsize=(10, 4))

# Add labels and title
plt.title("Existence of National Strategy by Year in Africa")
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show the plot
plt.legend(title='National Strategy')
plt.tight_layout()
plt.show()

# %%
top_5_NS = africa_NS[africa_NS['Country'].isin(top_5)]
top_5_NS
# Out:
#           Country Code  Year Existence of National Strategy
# 100      Djibouti  DJI  2021               Strategy adopted
# 118      Eswatini  SWZ  2019          Developing a strategy
# 119      Eswatini  SWZ  2020          Developing a strategy
# 302  South Africa  ZAF  2019       Strategy operationalized
# 303  South Africa  ZAF  2020       Strategy operationalized
# 304  South Africa  ZAF  2022       Strategy operationalized

# %%
least_5_NS = africa_NS[africa_NS['Country'].isin(least_5)]
least_5_NS
# Out:
#     Country Code  Year Existence of National Strategy
# 36    Benin  BEN  2019               Strategy adopted
# 37    Benin  BEN  2020               Strategy adopted
# 272  Rwanda  RWA  2019       Strategy operationalized
# 273  Rwanda  RWA  2020       Strategy operationalized

# %% [markdown]
# # 3. SHARE OF EDUCATION IN GOVERNMENT EXPENDITURE

# %%
education_share = pd.merge(education_share, country_code, left_on='Entity', right_on='name', how='left')
education_share
columns_to_drop = ['name', 'alpha-2', 'alpha-3', 'country-code', 'sub-region']
columns_to_drop = [col for col in columns_to_drop if col in education_share.columns]
education_share.drop(columns=columns_to_drop, inplace=True)
education_share.rename(columns={'Entity': 'Country', 'region': 'Continent'}, inplace=True)
africa_education_share = education_share[education_share['Continent'] == 'Africa']
africa_education_share
# Out:
#        Country Code  Year  \
# 39     Algeria  DZA  2008
# 40     Algeria  DZA  2009
# 41     Algeria  DZA  2012
# 42     Algeria  DZA  2013
# 43     Algeria  DZA  2014
# ...        ...  ...   ...
# 4099  Zimbabwe  ZWE  2015
# 4100  Zimbabwe  ZWE  2016
# 4101  Zimbabwe  ZWE  2017
# 4102  Zimbabwe  ZWE  2018
# 4103  Zimbabwe  ZWE  2020
#
#       Government expenditure on education, total (% of government expenditure)  \
# 39                                            11.428350
# 40                                            14.340000
# 41                                            15.983726
# 42                                            17.646034
# 43                                            16.469202
# ...                                                 ...
# 4099                                          29.470830
# 4100                                          23.527080
# 4101                                          20.874200
# 4102                                          19.039840
# 4103                                          15.666611
#
#      Continent
# 39      Africa
# 40      Africa
# 41      Africa
# 42      Africa
# 43      Africa
# ...        ...
# 4099    Africa
# 4100    Africa
# 4101    Africa
# 4102    Africa
# 4103    Africa
#
# [891 rows x 5 columns]

# %%
africa_education_share.rename(columns={'Government expenditure on education, total (% of government expenditure)' : 'Government Expenditure'}, inplace=True)

# %%
per_country_expenditure = africa_education_share.groupby(['Country'])['Government Expenditure'].mean().sort_values(ascending=False)
per_country_expenditure.head(10)
# Out:
# Country
# Tunisia         24.222804
# Namibia         23.473509
# Zimbabwe        22.837985
# Ghana           21.619277
# Lesotho         20.770853
# Togo            20.628810
# Senegal         20.264911
# Eswatini        20.137310
# Sierra Leone    19.768435
# Djibouti        19.722320
# Name: Government Expenditure, dtype: float64

# %%
per_country_expenditure = africa_education_share.groupby(['Year'])['Government Expenditure'].mean().sort_values(ascending=False)
plt.figure(figsize=(12,4))
per_country_expenditure.plot(kind='bar')
plt.show();

# %%
top_unemployment_exp = africa_education_share[africa_education_share['Country'].isin(top_5)]
top_unemployment_exp.groupby(['Country'])['Government Expenditure'].mean()
# Out:
# Country
# Djibouti        19.722320
# Eswatini        20.137310
# Lesotho         20.770853
# Libya            8.138730
# South Africa    18.966115
# Name: Government Expenditure, dtype: float64

# %%
least_unemployment_exp = africa_education_share[africa_education_share['Country'].isin(least_5)]
least_unemployment_exp.groupby(['Country'])['Government Expenditure'].mean()
# Out:
# Country
# Benin      18.879020
# Burundi    17.221021
# Chad       12.208346
# Niger      16.867470
# Rwanda     14.934174
# Name: Government Expenditure, dtype: float64

# %%
top_5 = df.index.values
colors=['b', 'g', 'r', 'k', 'c' ]

for index, country in enumerate(top_5):
    country_data = africa_education_share[africa_education_share['Country'] == country]
    plt.plot(country_data['Year'], country_data['Government Expenditure'], c=colors[index], label=country)

plt.legend()
plt.show()

# %%
least_5 = df1.index.values
colors=['b', 'g', 'r', 'k', 'c' ]

for index, country in enumerate(least_5):
    country_data = africa_education_share[africa_education_share['Country'] == country]
    plt.plot(country_data['Year'], country_data['Government Expenditure'], c=colors[index], label=country)

plt.legend()
plt.show()

# %% [markdown]
# # 4. ACCESS TO ELECTRICITY

# %%
access_to_electricity

merged_access = pd.merge(access_to_electricity, country_code, left_on='Entity', right_on='name', how='left')
columns_to_drop = ['name', 'alpha-2', 'alpha-3', 'country-code', 'sub-region']
columns_to_drop = [col for col in columns_to_drop if col in merged_access.columns]
merged_access.drop(columns=columns_to_drop, inplace=True)
merged_access.rename(columns={'Entity': 'Country', 'region': 'Continent', 
                              'Access to electricity (% of population)': 'Access to electricity'}, inplace=True)

merged_access['Cotinent'] = merged_access['Continent'].astype(str)
merged_access['Cotinent'] = merged_access['Continent'].str.strip()

access_in_africa = merged_access[merged_access['Continent'] == 'Africa']
access_in_africa = access_in_africa.drop(columns=['Cotinent'])
access_in_africa
# Out:
#        Country Code  Year  Access to electricity Continent
# 52     Algeria  DZA  2000              98.973100    Africa
# 53     Algeria  DZA  2001              98.966870    Africa
# 54     Algeria  DZA  2002              98.953060    Africa
# 55     Algeria  DZA  2003              98.934010    Africa
# 56     Algeria  DZA  2004              98.912080    Africa
# ...        ...  ...   ...                    ...       ...
# 6228  Zimbabwe  ZWE  2016              42.561730    Africa
# 6229  Zimbabwe  ZWE  2017              44.178635    Africa
# 6230  Zimbabwe  ZWE  2018              45.572647    Africa
# 6231  Zimbabwe  ZWE  2019              46.781475    Africa
# 6232  Zimbabwe  ZWE  2020              52.747670    Africa
#
# [1248 rows x 5 columns]

# %%
percentage_accessibility = access_in_africa.groupby(['Country'])[['Access to electricity']].mean().sort_values(by='Access to electricity', ascending=False)
percentage_accessibility.head(10)
# Out:
#                    Access to electricity
# Country
# Mauritius                      99.288581
# Algeria                        99.108146
# Egypt                          98.220330
# Tunisia                        97.307407
# Seychelles                     96.454384
# Gabon                          84.270413
# Libya                          82.114828
# Morocco                        80.562376
# South Africa                   79.231326
# Equatorial Guinea              65.893630

# %%
yearly_accessibility = access_in_africa.groupby(['Year'])[['Access to electricity']].mean()
yearly_accessibility.head(10)
# Out:
#       Access to electricity
# Year
# 1990              43.260391
# 1991              31.239611
# 1992              31.443107
# 1993              30.055181
# 1994              34.303391
# 1995              33.700934
# 1996              34.585017
# 1997              32.558737
# 1998              32.155793
# 1999              32.655429

# %%
yearly_accessibility.plot()
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # 5. TOTAL NUMBER OF LIMITED LIABILITY COMPANIES

# %%
firm_history

merged_LLC = pd.merge(firm_history, country_code, left_on='Economy', right_on='name', how='left')
columns_to_drop = ['name', 'alpha-2', 'alpha-3', 'country-code', 'sub-region']
columns_to_drop = [col for col in columns_to_drop if col in merged_LLC.columns]
merged_LLC.drop(columns=columns_to_drop, inplace=True)
merged_LLC.rename(columns={'region': 'Continent', 
                           'TOTAL Number of \nLimited Liability Companies':'Number of LLC',
                          'Economy': 'Country'}, inplace=True)
merged_LLC
merged_LLC['Continent'] = merged_LLC['Continent'].astype(str)
merged_LLC['Continent'] = merged_LLC['Continent'].str.strip()

LLC_in_africa = merged_LLC[merged_LLC['Continent'] == 'Africa']
LLC_in_africa['Year'] = LLC_in_africa['Year'].astype(int)
# LLC_in_africa['Year'] = LLC_in_africa['Year'].str.strip('.')
LLC_in_africa.reset_index()
# Out:
#      index   Country  Adult population  Year  Number of LLC  \
# 0       25   Algeria        22354242.0  2006        45055.0
# 1       26   Algeria        22845303.0  2007        51909.0
# 2       27   Algeria        23315424.0  2008        53825.0
# 3       28   Algeria        23766657.0  2009        59346.0
# 4       29   Algeria        24198798.0  2010        61674.0
# ..     ...       ...               ...   ...            ...
# 173   1517  Zimbabwe         7642765.0  2016       158627.0
# 174   1518  Zimbabwe         7759792.0  2017       168145.0
# 175   1519  Zimbabwe         7892169.0  2018       184955.0
# 176   1520  Zimbabwe         8034692.0  2019       209983.0
# 177   1521  Zimbabwe         8185716.0  2020       230256.0
#
#      Total business density rate Continent
# 0                       2.015501    Africa
# 1                       2.272196    Africa
# 2                       2.308558    Africa
# 3                       2.497028    Africa
# 4                       2.548639    Africa
# ..                           ...       ...
# 173                    20.755185    Africa
# 174                    21.668751    Africa
# 175                    23.435256    Africa
# 176                    26.134543    Africa
# 177                    28.128999    Africa
#
# [178 rows x 7 columns]

# %%
LLC_in_africa['Year'].astype(str)
total_LLC = LLC_in_africa.groupby(['Country'])[['Number of LLC', 'Total business density rate']].mean()
total_LLC.head(10)
# Out:
#             Number of LLC  Total business density rate
# Country
# Algeria      7.144138e+04                     2.849472
# Botswana     1.565929e+05                   124.193940
# Ethiopia     1.025020e+05                     1.731497
# Gabon        8.658154e+03                     7.840060
# Lesotho      2.324260e+04                    18.372837
# Madagascar   1.442240e+04                     1.031626
# Mauritania   2.284667e+03                     0.933893
# Morocco      3.265585e+05                    14.455064
# Nigeria      1.058714e+06                    11.252799
# Rwanda       3.866633e+04                     5.706597

# %%
yearly_LLC =LLC_in_africa.groupby(['Year'])[['Number of LLC', 'Total business density rate']].mean()
yearly_LLC.head(10)
# Out:
#       Number of LLC  Total business density rate
# Year
# 2006   98929.000000                    11.625391
# 2007  109233.200000                    12.574259
# 2008  121109.100000                    13.610735
# 2009  121973.272727                    13.562860
# 2010  134203.636364                    14.873170
# 2011  144430.166667                    16.190065
# 2012  159680.166667                    17.928439
# 2013  174246.833333                    19.578493
# 2014  175409.000000                    19.829910
# 2015  189754.307692                    21.781194

# %%
fig, ax= plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(yearly_LLC['Number of LLC'])
ax[0].set_title('Variation of LLC with Years')
ax[1].plot(yearly_LLC['Total business density rate'])
ax[1].set_title('Total Business Desnity Rate in Africa Over the Years')
# Out:
# Text(0.5, 1.0, 'Total Business Desnity Rate in Africa Over the Years')

# %% [markdown]
# OBSERVATIONS AND RECOMMENDATIONS
# The current analysis of unemployment data in Africa has uncovered notable trends, particularly highlighting a surge in unemployment prevalence within the working-age population as the population increases, notably in the years 2020 and 2021. This surge is predominantly attributed to Djibouti and South Africa. Additionally, the study sheds light on the challenges faced by the majority of African countries in implementing national strategies for youth employment. A concerning observation is the rapid decrease in the number of countries successfully operationalizing such strategies. The analysis also reveals a sharp decline in educational budgets, particularly during 2020 and 2021 when the highest unemployment rates were recorded. Furthermore, a disproportionate increase in the creation of private limited liability companies was observed.
#
# A. Key Observations:
#
# 1. Unemployment Prevalence:
#
# There is a discernible upswing in unemployment prevalence, particularly prominent in 2020 and 2021.
# Djibouti and South Africa significantly contribute to this surge. A similar trend in unemployment rate was alos reproted by Statista (2023).
#
# 2. Youth Employment Strategies:
#
# Most African countries face challenges in implementing national strategies for youth employment.
# A rapid decline is observed in the successful operationalization of these strategies.
#
# 3. Educational Budgets:
#
# A sharp decrease in educational budgets is noted, coinciding with the peak of unemployment rates in 2020 and 2021.
#
# 4. Private Limited Liability Companies:
#
# There is a disproportionate increase in the establishment of private limited liability companies.
#
# These observations are corroborated by findings from a systematic review conducted by Ongbali, Afolalu and UdO (2019) whereby unemployemnt rate was found to be uderpinned byfast population growth, rural to urban migration and lack of employable skills and experience among the youth fast population growth, rural to urban migration and lack of employable skills and experience among the youth.
#
# B. RECOMMENDATIONS:
#
# 1. Operationalization of Youth Employment Strategies:
#
# Urgent attention and action are needed to operationalize youth employment and empowerment strategies across African nations.
#
# 2. Increase in Educational Budget:
#
# A strategic increase in educational budgets is recommended to address the challenges posed by the observed downturn.
#
# C. LIMITATIONS:
# 1. Data Disproportion:
#
# The datasets exhibit a disproportion in distribution, with not all countries uniformly represented across all study years.
#
# 2. Correspondence Disparities:
#
# Challenges in value representation hindered the optimum correspondence of incidence.
#
# D. CONCLUSION:
# This analysis provides valuable insights into the unemployment landscape in Africa. Despite the limitations identified, the findings lay the groundwork for informed decision-making. To enhance the richness of our analysis, it is strongly recommended that incorporating datasets from other countries or continents with lower incidence rates for a comprehensive comparison of incidence patterns and underlying factors should be considered.
#
# REFERENCES
#
# Ongbali, S.O., Afolalu, S.A. and Udo, M.O., 2019. Factors causing youth unemployment problem in Nigeria: A review. International Journal of Mechanical Engineering and Technology, 10(1), pp.1874-1879.
#
# https://www.statista.com/statistics/1319860/unemployment-rate-in-africa/#:~:text=The%20unemployment%20rate%20in%20Africa,2024%20at%20around%2030%20percent.

# %% [markdown]
# # BUILDING MACHINE LEARNING MODELS

# %% [markdown]
# STEP 1: FEATURE ENGINEERING
