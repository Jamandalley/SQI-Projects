# %%
import pandas as pd
import numpy as np

submem = pd.read_csv(r"C:\Users\USER\Downloads\subscribed_members_export_299cbfa887.csv")
submem
# Out:
#                     Email Address                      First Name  Last Name  \
# 0          ioyeyemi@unimed.edu.ng               Ifeoluwa Temitayo    Oyeyemi
# 1           ndeesorhope@gmail.com                            HOPE    NDEESOR
# 2      abigaeladefolalu@gmail.com                         Abigael  Adefolalu
# 3          owenighodaro@gmail.com                  Faith Iriowen      Ojika
# 4               celecnn@gmail.com  NWANGWU NZUBECHUKWU CELESTINE         NaN
# ...                           ...                             ...        ...
# 4594        othnielenyo@gmail.com                    Othniel Enyo     Friday
# 4595        nzeribeella@gmail.com        Emmanuella (Ella) Chisom         Nz
# 4596   davidrichardlucz@gmail.com                RICHARD OPEYEMI       DAVID
# 4597     Abdoulmalle100@gmail.com               Abdulhamid Babayo  Abdullahi
# 4598  ifeoluwaanthonia1@gmail.com               Ifeoluwa Anthonia    Kehinde
#
#      Address Phone Number Birthday  \
# ...

# %%
intro_data = pd.read_csv(r"C:\Users\USER\Downloads\Introduction to Basic Bioinformatics and Immunoinformatics-1.csv", encoding="latin-1")
intro_data
# Out:
#                 Timestamp  Score      Surname   First name      Other names  \
# 0      12/15/2023 9:46:52      0  Ogunmodede          Sola            Peter
# 1      12/15/2023 9:56:57      0     OLAKANMI   OLUWAKEMI           DEBORAH
# 2     12/15/2023 10:01:32      0      Hamzat   Islamiyyah          Olamide
# 3     12/15/2023 10:03:18      0       Ogoke        Naomi         Chinyere
# 4     12/15/2023 10:03:18      0        Idris    Damilola         Oreoluwa
# ...                   ...    ...          ...          ...              ...
# 2639    1/2/2024 12:05:00      0    Mashavave      Praise         Tinodashe
# 2640    1/2/2024 12:15:25      0      Dlodlo     Sinikiwe      Thembelihle
# 2641    1/2/2024 12:22:17      0  ALADEMEHIN     AYOMIKUN            PETER
# 2642    1/2/2024 12:55:35      0       Tayab           Ali  Tayab Ali Khan
# 2643    1/2/2024 13:19:43      0         Lagu      Inyani        John Lino
#
#                            Email Address Whatsapp number  \
# ...

# %%
cleaned_mem = pd.read_csv(r"C:\Users\USER\Downloads\cleaned_members_export_299cbfa887.csv")
cleaned_mem
# Out:
#                         Email Address              First Name Last Name  \
# 0   amen.ekhosuehi4life2001@gmail.com          Amen Ekhosuehi       NaN
# 1                  Habees28@yahoo.com         Suliat Abisola   Olatunde
# 2           vicade.integrit@gmail.com  Falade Adeola Victoria       NaN
# 3                   Imuisa1@gmail.com             IMRAN AHMED       ISA
# 4            noramichaeloo1@gmail.com    Michael Nora Asheazi       NaN
# ..                                ...                     ...       ...
# 70     oluwaseunsamuel12014@gmail.com          SAMUEL OYEDELE       NaN
# 71    akinleyeopeyemi908.ao@gmail.com      Opeyemi Elizabeth     Akinle
# 72          jennifergakor72@gmail.com               Jennifer      Gakor
# 73              sylbinsuzan@gmail.com   Attah Akolo Sylvester       NaN
# 74           mquhammadneema@gmail.com           Umar Mohammed    Hassan
#
#     Address  Phone Number  Birthday               Institution Gender  \
# ...

# %%
Full_name = cleaned_mem['First Name'].str.split()
Full_name
# Out:
# 0              [Amen, Ekhosuehi]
# 1              [Suliat, Abisola]
# 2     [Falade, Adeola, Victoria]
# 3                 [IMRAN, AHMED]
# 4       [Michael, Nora, Asheazi]
#                  ...
# 70             [SAMUEL, OYEDELE]
# 71          [Opeyemi, Elizabeth]
# 72                    [Jennifer]
# 73     [Attah, Akolo, Sylvester]
# 74              [Umar, Mohammed]
# Name: First Name, Length: 68, dtype: object

# %%
cleaned_mem = cleaned_mem.dropna(subset=['First Name'])
cleaned_mem
# Out:
#                         Email Address              First Name Last Name  \
# 0   amen.ekhosuehi4life2001@gmail.com          Amen Ekhosuehi       NaN
# 1                  Habees28@yahoo.com         Suliat Abisola   Olatunde
# 2           vicade.integrit@gmail.com  Falade Adeola Victoria       NaN
# 3                   Imuisa1@gmail.com             IMRAN AHMED       ISA
# 4            noramichaeloo1@gmail.com    Michael Nora Asheazi       NaN
# ..                                ...                     ...       ...
# 70     oluwaseunsamuel12014@gmail.com          SAMUEL OYEDELE       NaN
# 71    akinleyeopeyemi908.ao@gmail.com      Opeyemi Elizabeth     Akinle
# 72          jennifergakor72@gmail.com               Jennifer      Gakor
# 73              sylbinsuzan@gmail.com   Attah Akolo Sylvester       NaN
# 74           mquhammadneema@gmail.com           Umar Mohammed    Hassan
#
#     Address  Phone Number  Birthday               Institution Gender  \
# ...

# %%
first_nam = [name[0] for name in cleaned_mem['First Name'].str.split()]
first_nam
# Out:
# ['Amen',
#  'Suliat',
#  'Falade',
#  'IMRAN',
#  'Michael',
#  'Umar',
#  'OYELEKE,',
#  'Bukar',
#  'Divya',
#  'Bukar',
#  'Uchenna',
#  'Daniella',
#  'Orilabawaye',
#  'Ibrahim',
#  'Kehinde',
#  'Abisola',
#  'Ekokodje',
#  'Qaisar',
#  'Zahrau',
#  'AREMU,',
#  'Mwangi',
#  'Ndoye',
#  'VICTOR',
#  'Quadri',
#  'Yahuza',
#  'Faith',
#  'Kenneth',
#  'Igho',
#  'Ugboaja',
#  'Fatima',
#  'Oderinu',
#  'Chinoso',
#  'Sarmadi',
#  'Osemudiame',
#  'Kissinger',
#  'OLUWASEYI',
#  'Abigail',
#  'Riya',
#  'Abiona',
#  'Emmanuel',
#  'Ayodeji',
#  'Tolulope',
#  'Al-Mahroof',
#  'ANUOLUWAPO',
#  'Cecilia',
#  'Abigeal',
#  'Jesutomisola',
#  'OPEYEMI',
#  'Julianah',
#  'Aliyu',
#  'Falade',
#  'Bukola',
#  'Charles',
#  'Okoh',
#  'Olabode',
#  'Chukwunonso',
#  'Oluwaseun',
#  'Ibrahim',
#  'Seun',
#  'Violet',
#  'Akiroso',
#  'Adeniyi',
#  'Abdul',
#  'SAMUEL',
#  'Opeyemi',
#  'Jennifer',
#  'Attah',
#  'Umar']

# %%
# first_name = []
# for names in Full_name:
#     if len(names) == 0:
#         first_name.append(np.nan)
#     if len(names) == 2 or 3:
#         first_name.append(names[0])
#     else:
#         pass

# print(first_name)

# %%
cleaned_mem['First_Name'] = [name[0] for name in cleaned_mem['First Name'].str.split()]
cleaned_mem
# Out:
#                         Email Address              First Name Last Name  \
# 0   amen.ekhosuehi4life2001@gmail.com          Amen Ekhosuehi       NaN
# 1                  Habees28@yahoo.com         Suliat Abisola   Olatunde
# 2           vicade.integrit@gmail.com  Falade Adeola Victoria       NaN
# 3                   Imuisa1@gmail.com             IMRAN AHMED       ISA
# 4            noramichaeloo1@gmail.com    Michael Nora Asheazi       NaN
# ..                                ...                     ...       ...
# 70     oluwaseunsamuel12014@gmail.com          SAMUEL OYEDELE       NaN
# 71    akinleyeopeyemi908.ao@gmail.com      Opeyemi Elizabeth     Akinle
# 72          jennifergakor72@gmail.com               Jennifer      Gakor
# 73              sylbinsuzan@gmail.com   Attah Akolo Sylvester       NaN
# 74           mquhammadneema@gmail.com           Umar Mohammed    Hassan
#
#     Address  Phone Number  Birthday               Institution Gender  \
# ...

# %%
cleaned_mem['Middle Name'] = [name[1] if len(name) >= 2 else np.nan for name in Full_name]
cleaned_mem
# Out:
#                         Email Address              First Name Last Name  \
# 0   amen.ekhosuehi4life2001@gmail.com          Amen Ekhosuehi       NaN
# 1                  Habees28@yahoo.com         Suliat Abisola   Olatunde
# 2           vicade.integrit@gmail.com  Falade Adeola Victoria       NaN
# 3                   Imuisa1@gmail.com             IMRAN AHMED       ISA
# 4            noramichaeloo1@gmail.com    Michael Nora Asheazi       NaN
# ..                                ...                     ...       ...
# 70     oluwaseunsamuel12014@gmail.com          SAMUEL OYEDELE       NaN
# 71    akinleyeopeyemi908.ao@gmail.com      Opeyemi Elizabeth     Akinle
# 72          jennifergakor72@gmail.com               Jennifer      Gakor
# 73              sylbinsuzan@gmail.com   Attah Akolo Sylvester       NaN
# 74           mquhammadneema@gmail.com           Umar Mohammed    Hassan
#
#     Address  Phone Number  Birthday               Institution Gender  \
# ...

# %%
cleaned_mem['other_name'] = [name[2] if len(name) >= 3 else np.nan for name in Full_name]
cleaned_mem
# Out:
#                         Email Address              First Name Last Name  \
# 0   amen.ekhosuehi4life2001@gmail.com          Amen Ekhosuehi       NaN
# 1                  Habees28@yahoo.com         Suliat Abisola   Olatunde
# 2           vicade.integrit@gmail.com  Falade Adeola Victoria       NaN
# 3                   Imuisa1@gmail.com             IMRAN AHMED       ISA
# 4            noramichaeloo1@gmail.com    Michael Nora Asheazi       NaN
# ..                                ...                     ...       ...
# 70     oluwaseunsamuel12014@gmail.com          SAMUEL OYEDELE       NaN
# 71    akinleyeopeyemi908.ao@gmail.com      Opeyemi Elizabeth     Akinle
# 72          jennifergakor72@gmail.com               Jennifer      Gakor
# 73              sylbinsuzan@gmail.com   Attah Akolo Sylvester       NaN
# 74           mquhammadneema@gmail.com           Umar Mohammed    Hassan
#
#     Address  Phone Number  Birthday               Institution Gender  \
# ...

# %%
cleaned_mem['Last_Name'] = cleaned_mem['other_name'].fillna(cleaned_mem['Last Name'])
cleaned_mem
# Out:
#                         Email Address              First Name Last Name  \
# 0   amen.ekhosuehi4life2001@gmail.com          Amen Ekhosuehi       NaN
# 1                  Habees28@yahoo.com         Suliat Abisola   Olatunde
# 2           vicade.integrit@gmail.com  Falade Adeola Victoria       NaN
# 3                   Imuisa1@gmail.com             IMRAN AHMED       ISA
# 4            noramichaeloo1@gmail.com    Michael Nora Asheazi       NaN
# ..                                ...                     ...       ...
# 70     oluwaseunsamuel12014@gmail.com          SAMUEL OYEDELE       NaN
# 71    akinleyeopeyemi908.ao@gmail.com      Opeyemi Elizabeth     Akinle
# 72          jennifergakor72@gmail.com               Jennifer      Gakor
# 73              sylbinsuzan@gmail.com   Attah Akolo Sylvester       NaN
# 74           mquhammadneema@gmail.com           Umar Mohammed    Hassan
#
#     Address  Phone Number  Birthday               Institution Gender  \
# ...

# %%
# YOU CAN THEN DROP THE 'Last Name' and 'Other Name'
